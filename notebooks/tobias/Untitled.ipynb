# %%
import xarray as xr
import h5py

import matplotlib.pyplot as plt

# %%
r=122

# %%
hf=h5py.File(f'../../hdf5/smalldata/xppl1001021_Run{r:04}.h5')

# %%
list(hf.keys())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 list(hf.keys())
#
# File /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.54-py3/lib/python3.9/_collections_abc.py:806, in MappingView.__len__(self)
#     805 def __len__(self):
# --> 806     return len(self._mapping)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.54-py3/lib/python3.9/site-packages/h5py/_hl/group.py:466, in Group.__len__(self)
#     463 @with_phil
#     464 def __len__(self):
#     465     """ Number of members attached to this group """
# --> 466     return self.id.get_num_objs()
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# ...

# %%
i=hf['jungfrau1M_alcove']['pyfai_azav'][()]#.keys()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [99], line 1
# ----> 1 i=hf['jungfrau1M_alcove']['pyfai_azav'][()]#.keys()
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.54-py3/lib/python3.9/site-packages/h5py/_hl/group.py:328, in Group.__getitem__(self, name)
#     326         raise ValueError("Invalid HDF5 object reference")
#     327 elif isinstance(name, (bytes, str)):
# --> 328     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     329 else:
#     330     raise TypeError("Accessing a group is done with bytes or str, "
#     331                     " not {}".format(type(name)))
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# ...

# %%
I=i.mean(axis=0)

# %%
plt.figure()

plt.plot(I)
